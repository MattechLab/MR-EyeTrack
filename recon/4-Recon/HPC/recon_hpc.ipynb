# %% [markdown]
# Upload files to server

# %%
# code folder
rsync -avz /home/debi/jaime/repos/MR-EyeTrack/recon/ chacha:/home/jaime.barrancohernandez/shared_datasets/mreyetrack/recon/

# pulseq folder
ssh chacha 'mkdir -p /home/jaime.barrancohernandez/shared_datasets/mreyetrack/data/study/pulseq' && rsync -avz /home/debi/jaime/repos/MR-EyeTrack/data/study/pulseq/ chacha:/home/jaime.barrancohernandez/shared_datasets/mreyetrack/data/study/pulseq/

# rawdata folder
ssh chacha 'mkdir -p /home/jaime.barrancohernandez/shared_datasets/mreyetrack/data/study/sub-004/rawdata/' && rsync -avz /home/debi/jaime/repos/MR-EyeTrack/data/study/sub-004/rawdata/sub-004_HC.dat chacha:/home/jaime.barrancohernandez/shared_datasets/mreyetrack/data/study/sub-004/rawdata/

# C (coil sensitivity maps) file
ssh chacha 'mkdir -p /home/jaime.barrancohernandez/shared_datasets/mreyetrack/data/study/sub-004/recon' && rsync -avz data/study/sub-004/recon/C.mat chacha:/home/jaime.barrancohernandez/shared_datasets/mreyetrack/data/study/sub-004/recon/

# mitosius
ssh chacha 'mkdir -p /home/jaime.barrancohernandez/shared_datasets/mreyetrack/data/study/sub-004/recon/mitosius/woBin' && rsync -avz data/study/sub-004/recon/mitosius/woBin/ chacha:/home/jaime.barrancohernandez/shared_datasets/mreyetrack/data/study/sub-004/recon/mitosius/woBin/

# %% [markdown]
# Download files from server

# %%
# output folder
rsync -avz chacha:/home/jaime.barrancohernandez/shared_datasets/mreyetrack/data/study/sub-004/recon/woBin/ /home/debi/jaime/repos/MR-EyeTrack/data/study/sub-004/recon/woBin/

# %% [markdown]
# Interactive session chacha

# %%
srun --cpus-per-task=20 --time=03:00:00 --mem=480G --job-name=mreyetrack --nodelist=chacha --pty apptainer shell \
--bind /home/jaime.barrancohernandez/shared_datasets/mreyetrack/recon:/usr/src/app/scripts \
--bind /home/jaime.barrancohernandez/mnt/jaime.barranco/MR-EyeTrack/data/study:/usr/src/app/data/study \
--bind /home/jaime.barrancohernandez/shared_datasets/pulseq:/usr/src/app/pulseq \
--writable-tmpfs --fakeroot \
--env MLM_LICENSE_FILE=27000@matlablm.hevs.ch \
/home/jaime.barrancohernandez/shared_datasets/monalisa/monalisa_251215.sif

# %%
$ chmod -R ugo+x /usr/src/app/scripts
$ matlab
>> addpath(genpath('/usr/src/app/'))
>> compile_mex_for_monalisa
>> run('/usr/src/app/scripts/4-Recon/HPC/S4_recon_chacha_4fr_woBin_pulseq.m')
>> exit
$ exit

# %% [markdown]
# Mount filer on chacha/disco

# %%
sudo /bin/mount -t cifs //filer01.hevs.ch/fs_projets/MatTechLab /home/jaime.barrancohernandez/mnt/ -o username=jaime.barranco -o uid=jaime.barrancohernandez -o gid=jaime.barrancohernandez -o vers=3.0

# %% [markdown]
# Batch job

# %%
sbatch /home/jaime.barrancohernandez/shared_datasets/mreyetrack/recon/4-Recon/HPC/recon.sh

# %% [markdown]
# Check queue

# %%
squeue -u jaime.barrancohernandez

# %% [markdown]
# Copy files from filer

# %%
rsync -avz /mnt/filer01/MatTechLab/jaime.barranco/MR-EyeTrack/data/study/sub-005/ /home/debi/jaime/repos/MR-EyeTrack/data/study/sub-005/

# %% [markdown]
# Copy files to filer

# %%
rsync -avz /home/debi/jaime/repos/MR-EyeTrack/data/study/sub-005/ /mnt/filer01/MatTechLab/jaime.barranco/MR-EyeTrack/data/study/sub-005
