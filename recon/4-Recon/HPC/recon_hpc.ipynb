# %% [markdown]
# Upload files to server

# %%
# code folder
rsync -avz /home/debi/jaime/repos/MR-EyeTrack/recon/ chacha:/home/jaime.barrancohernandez/shared_datasets/mreyetrack/recon/

# pulseq folder
ssh chacha 'mkdir -p /home/jaime.barrancohernandez/shared_datasets/mreyetrack/data/study/pulseq' && rsync -avz /home/debi/jaime/repos/MR-EyeTrack/data/study/pulseq/ chacha:/home/jaime.barrancohernandez/shared_datasets/mreyetrack/data/study/pulseq/

# rawdata folder
ssh chacha 'mkdir -p /home/jaime.barrancohernandez/shared_datasets/mreyetrack/data/study/sub-003/rawdata/' && rsync -avz /home/debi/jaime/repos/MR-EyeTrack/data/study/sub-003/rawdata/sub-003_HC.dat chacha:/home/jaime.barrancohernandez/shared_datasets/mreyetrack/data/study/sub-003/rawdata/

# C (coil sensitivity maps) file
ssh chacha 'mkdir -p /home/jaime.barrancohernandez/shared_datasets/mreyetrack/data/study/sub-003/recon' && rsync -avz data/study/sub-003/recon/C.mat chacha:/home/jaime.barrancohernandez/shared_datasets/mreyetrack/data/study/sub-003/recon/

# mitosius
ssh chacha 'mkdir -p /home/jaime.barrancohernandez/shared_datasets/mreyetrack/data/study/sub-003/recon/mitosius/woBin' && rsync -avz data/study/sub-003/recon/mitosius/woBin/ chacha:/home/jaime.barrancohernandez/shared_datasets/mreyetrack/data/study/sub-003/recon/mitosius/woBin/

# %% [markdown]
# Download files from server

# %%
# output folder
rsync -avz chacha:/home/jaime.barrancohernandez/shared_datasets/mreyetrack/data/study/sub-003/recon/woBin/ /home/debi/jaime/repos/MR-EyeTrack/data/study/sub-003/recon/woBin/

# %% [markdown]
# Interactive session chacha

# %%
srun --cpus-per-task=20 --time=03:00:00 --mem=480G --job-name=mreyetrack --nodelist=chacha --pty apptainer shell \
--bind /home/jaime.barrancohernandez/shared_datasets/mreyetrack/recon:/usr/src/app/scripts \
--bind /home/jaime.barrancohernandez/shared_datasets/mreyetrack/data/study:/usr/src/app/data/study \
--writable-tmpfs --fakeroot \
--env MLM_LICENSE_FILE=27000@matlablm.hevs.ch \
/home/jaime.barrancohernandez/shared_datasets/monalisa/monalisa_251215.sif

# %%
$ chmod -R ugo+x /usr/src/app/scripts
$ matlab
>> addpath(genpath('/usr/src/app/'))
>> compile_mex_for_monalisa
>> S4_recon_chacha_4fr_woBin_pulseq
>> exit
$ exit
